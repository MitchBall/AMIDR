# %%
radius9 = 1.318e-4 #NM9505
radius6 = 0.784e-4 #NMC640
radius8 = 1.736e-4 #NMC811
ionsat_inputs9 = [303.15, 275, 3.7, 66, 4.0, 149] #NM9505
ionsat_inputs6 = [303.15, 279, 3.8, 74, 4.1, 148] #NMC640
ionsat_inputs8 = [303.15, 275.5, 3.7, 70, 4.1, 178] #NMC811

from amidr import BIOCONVERT
from amidr import AMIDR
from amidr import BINAVERAGE

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/215'
formfiles = ['215_230224_C01.mpt', '215_230301_D_C01.mpt']
dfiles = ['215_230316_D4,2-3,7V_C01.mpt', '215_230320_D3,7-3,45V_C01.mpt']
cfiles = ['215_230324_C3,45-3,7V_C01.mpt', '215_230331_C3,7-4,2V_C01.mpt']
cellname = '215 NM9505 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/217'
formfiles = ['217_230224_C03.mpt', '217_230227_C03.mpt', '217_230301_D_C03.mpt']
dfiles = ['217_230316_D4,2-3,7V_C03.mpt', '217_230320_D3,7-3,45V_C03.mpt']
cfiles = ['217_230324_C3,45-3,7V_C03.mpt', '217_230331_C3,7-4,2V_C03.mpt']
cellname = '217 NM9505 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/243'
formfiles = ['243_230502_C06.mpt']
dfiles = ['243_230504_D4,2-3,7V_C06.mpt', '243_230507_D3,7-3,2V_C06.mpt']
cfiles = ['243_230509_C3,5-3,7V_C06.mpt', '243_230512_C3,7-4,2V_C06.mpt']
cellname = '243 NMC640 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/246'
formfiles = ['246_230502_C08.mpt']
dfiles = ['246_230504_D4,2-3,7V_C08.mpt', '246_230507_D3,7-3,2V_C08.mpt']
cfiles = ['246_230509_C3,5-3,7V_C08.mpt', '246_230512_C3,7-4,2V_C08.mpt']
cellname = '246 NMC640 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/259'
formfiles = ['259_230525_C09.mpt']
dfiles = ['259_230529_D4,2-3,7V_C09.mpt', '259_230531_D3,7-3,2V_C09.mpt']
cfiles = ['259_230601_C3,5-3,7V_C09.mpt', '259_230604_C3,7-4,2V_C09.mpt']
cellname = '259 NMC640 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/239'
formfiles = ['239_230502_C05.mpt']
dfiles = ['239_230504_D4,2-3,7V_C05.mpt', '239_230507_D3,7-3,2V_C05.mpt']
cfiles = ['239_230509_C3,5-3,7V_C05.mpt', '239_230515_C3,7-4,2V_C05.mpt']
cellname = '239 NMC811 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/272'
formfiles = ['272_230607_C06.mpt']
dfiles = ['272_230609_D4,2-3,7V_C06.mpt', '272_230612_D3,7-3,2V_C06.mpt']
cfiles = ['272_230615_C3,5-3,7V_C06.mpt', '272_230623_C3,7-4,2V_C06.mpt']
cellname = '272 NMC811 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/276'
formfiles = ['276_230607_C11.mpt']
dfiles = ['276_230609_D4,2-3,7V_C11.mpt', '276_230612_D3,7-3,2V_C11.mpt']
cfiles = ['276_230615_C3,5-3,7V_C11.mpt', '276_230623_C3,7-4,2V_C11.mpt']
cellname = '276 NMC811 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/266'
formfiles = ['266_230530_C08.mpt']
dfiles = ['266_230602_D4,2-3,95V_C08.mpt', '266_230604_D3,95-3,7V_C08.mpt', '266_230606_D3,7-3,45V_C08.mpt']
cfiles = ['266_230612_C3,5-3,7V_C08.mpt', '266_230619_C3,7-3,95V_C08.mpt', '266_230623_C3,95-4,2V_C08.mpt']
cellname = '266 NM9505 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/269'
formfiles = ['269_230530_C12.mpt']
dfiles = ['269_230602_D4,2-3,95V_C12.mpt', '269_230604_D3,95-3,7V_C12.mpt', '269_230606_D3,7-3,45V_C12.mpt']
cfiles = ['269_230612_C3,5-3,7V_C12.mpt', '269_230619_C3,7-3,95V_C12.mpt', '269_230623_C3,95-4,2V_C12.mpt']
cellname = '269 NM9505 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/270'
formfiles = ['270_230530_C02.mpt']
dfiles = ['270_230602_D4,2-3,95V_C02.mpt', '270_230604_D3,95-3,7V_C02.mpt', '270_230606_D3,7-3,45V_C02.mpt']
cfiles = ['270_230612_C3,5-3,7V_C02.mpt', '270_230619_C3,7-3,95V_C02.mpt', '270_230623_C3,95-4,2V_C02.mpt']
cellname = '270 NM9505 30C'
BIOCONVERT(cellpath, formfiles, dfiles, cfiles, cellname)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/215'
uhpc_file = '215 NM9505 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '215 NM9505 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/217'
uhpc_file = '217 NM9505 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '217 NM9505 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/243'
uhpc_file = '243 NMC640 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius6, R_corr=True, ionsat_inputs = ionsat_inputs6)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '243 NMC640 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius6, R_corr=True, ionsat_inputs = ionsat_inputs6)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/246'
uhpc_file = '246 NMC640 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius6, R_corr=True, ionsat_inputs = ionsat_inputs6)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '246 NMC640 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius6, R_corr=True, ionsat_inputs = ionsat_inputs6)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/259'
uhpc_file = '259 NMC640 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius6, R_corr=True, ionsat_inputs = ionsat_inputs6)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '259 NMC640 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius6, R_corr=True, ionsat_inputs = ionsat_inputs6)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/239'
uhpc_file = '239 NMC811 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius8, R_corr=True, ionsat_inputs = ionsat_inputs8)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '239 NMC811 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius8, R_corr=True, ionsat_inputs = ionsat_inputs8)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/272'
uhpc_file = '272 NMC811 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius8, R_corr=True, ionsat_inputs = ionsat_inputs8)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '272 NMC811 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius8, R_corr=True, ionsat_inputs = ionsat_inputs8)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/276'
uhpc_file = '276 NMC811 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius8, R_corr=True, ionsat_inputs = ionsat_inputs8)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '276 NMC811 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius8, R_corr=True, ionsat_inputs = ionsat_inputs8)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/266'
uhpc_file = '266 NM9505 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '266 NM9505 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/269'
uhpc_file = '269 NM9505 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '269 NM9505 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/270'
uhpc_file = '270 NM9505 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '270 NM9505 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True)
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/266'
uhpc_file = '266 NM9505 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True, force2e = True, parselabel = '2e')
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '266 NM9505 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True, force2e = True, parselabel = '2e')
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/269'
uhpc_file = '269 NM9505 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True, force2e = True, parselabel = '2e')
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '269 NM9505 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True, force2e = True, parselabel = '2e')
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)

cellpath = 'C:/Users/Mitch/Lab/Atlung Modeling/AMIDR/Analyzed Data/270'
uhpc_file = '270 NM9505 30C Discharge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True, force2e = True, parselabel = '2e')
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)
uhpc_file = '270 NM9505 30C Charge.csv'
amidr_data = AMIDR(cellpath, uhpc_file, single_pulse=True, force2e = True, parselabel = '2e')
amidr_data.plot_protocol()
amidr_data.plot_caps() 
fit_data = amidr_data.fit_atlung(radius9, R_corr=True, ionsat_inputs = ionsat_inputs9)
amidr_data.make_summary_graph(fit_data=fit_data)

path = 'C:/Users/Mitch/Lab/Atlung ModelingAMIDR/Analyzed Data'

cells = ['215', '217']
matname = 'NM9505 30C Old'
BINAVERAGE(path, cells, matname, binsize = 0.025)

cells = ['243', '246', '259']
matname = 'NMC640 30C'
BINAVERAGE(path, cells, matname, binsize = 0.025)

cells = ['239', '272', '276']
matname = 'NMC811 30C'
BINAVERAGE(path, cells, matname, binsize = 0.025)

cells = ['266', '269', '270']
matname = 'NM9505 30C'
BINAVERAGE(path, cells, matname, binsize = 0.025)

cells = ['266', '269', '270']
matname = 'NM9505 30C'
BINAVERAGE(path, cells, matname, binsize = 0.025, parselabel = '2e')
# Out:
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Form.csv
# 215_230320_D3,7-3,45V_C01.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Form.csv
# 217_230320_D3,7-3,45V_C03.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\243\243 NMC640 30C Form.csv
# 243_230507_D3,7-3,2V_C06.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\243\243 NMC640 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\243\243 NMC640 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\243\243 NMC640 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\243\243 NMC640 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\246\246 NMC640 30C Form.csv
# 246_230507_D3,7-3,2V_C08.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\246\246 NMC640 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\246\246 NMC640 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\246\246 NMC640 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\246\246 NMC640 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\259\259 NMC640 30C Form.csv
# 259_230531_D3,7-3,2V_C09.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\259\259 NMC640 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\259\259 NMC640 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\259\259 NMC640 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\259\259 NMC640 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\239\239 NMC811 30C Form.csv
# 239_230507_D3,7-3,2V_C05.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\239\239 NMC811 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\239\239 NMC811 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\239\239 NMC811 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\239\239 NMC811 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\272\272 NMC811 30C Form.csv
# 272_230612_D3,7-3,2V_C06.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\272\272 NMC811 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\272\272 NMC811 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\272\272 NMC811 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\272\272 NMC811 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\276\276 NMC811 30C Form.csv
# 276_230612_D3,7-3,2V_C11.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\276\276 NMC811 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\276\276 NMC811 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\276\276 NMC811 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\276\276 NMC811 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\266\266 NM9505 30C Form.csv
# 266_230606_D3,7-3,45V_C08.mpt ended prematurely. Labeling last pulse as unfinished to prevent analysis.
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\266\266 NM9505 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\266\266 NM9505 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\266\266 NM9505 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\266\266 NM9505 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\269\269 NM9505 30C Form.csv
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\269\269 NM9505 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\269\269 NM9505 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\269\269 NM9505 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\269\269 NM9505 30C Relax Match.jpg
# Formation data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\270\270 NM9505 30C Form.csv
# Discharge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\270\270 NM9505 30C Discharge.csv
# Charge data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\270\270 NM9505 30C Charge.csv
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\270\270 NM9505 30C Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\270\270 NM9505 30C Relax Match.jpg
# 215 NM9505 30C Discharge
# Create directory: C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Discharge
# Working on cell: 215 NM9505 30C
# Positive electrode active mass: 0.000601 g
# Input cell capacity: 0.000135 Ah
# 3-electrode data detected. Using working potential for calculations and complete cell potential for labelling.
# First signature curve step: 1
# Last signature curve step: 93
# Starting voltage: 4.087 V
# Ending voltage: 3.445 V
# Found 31 charge or discharge steps in signature curve sequences.
# Found 31 signature curves.
# Voltage interval labels: ['4.087 V - 4.083 V', '4.083 V - 4.060 V', '4.060 V - 4.035 V', '4.035 V - 4.009 V', '4.009 V - 3.984 V', '3.984 V - 3.960 V', '3.960 V - 3.936 V', '3.936 V - 3.911 V', '3.911 V - 3.886 V', '3.886 V - 3.860 V', '3.860 V - 3.834 V', '3.834 V - 3.808 V', '3.808 V - 3.783 V', '3.783 V - 3.759 V', '3.759 V - 3.734 V', '3.734 V - 3.710 V', '3.720 V - 3.680 V', '3.680 V - 3.656 V', '3.656 V - 3.634 V', '3.634 V - 3.614 V', '3.614 V - 3.596 V', '3.596 V - 3.580 V', '3.580 V - 3.566 V', '3.566 V - 3.559 V', '3.559 V - 3.552 V', '3.552 V - 3.547 V', '3.547 V - 3.542 V', '3.542 V - 3.539 V', '3.539 V - 3.540 V', '3.540 V - 3.540 V', '3.540 V - 3.539 V']
# Found 31 voltage intervals.
# 3.540 V - 3.540 V removed due to not having 4 or more datapoints with relative change in capacity ($τ$) above 0.001
# Parsed data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Discharge\215 NM9505 30C Discharge Parsed.xlsx
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Discharge\215 NM9505 30C Discharge Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Discharge\215 NM9505 30C Discharge Parsed.jpg
# Optimum Parameters: Log(Dc) Log(P) Log(P/Dc)
# 4.087 V - 4.083 V: [-11.309  -1.365   9.944]
# 4.083 V - 4.060 V: [-11.53   -1.545   9.985]
# 4.060 V - 4.035 V: [-11.665  -1.558  10.107]
# 4.035 V - 4.009 V: [-11.821  -1.554  10.267]
# 4.009 V - 3.984 V: [-11.885  -1.466  10.419]
# 3.984 V - 3.960 V: [-11.704  -1.35   10.355]
# 3.960 V - 3.936 V: [-11.623  -1.389  10.234]
# 3.936 V - 3.911 V: [-11.586  -1.466  10.12 ]
# 3.911 V - 3.886 V: [-11.524  -1.485  10.039]
# 3.886 V - 3.860 V: [-11.524  -1.511  10.013]
# 3.860 V - 3.834 V: [-11.56   -1.518  10.042]
# 3.834 V - 3.808 V: [-11.627  -1.507  10.119]
# 3.808 V - 3.783 V: [-11.688  -1.476  10.213]
# 3.783 V - 3.759 V: [-11.705  -1.407  10.299]
# 3.759 V - 3.734 V: [-11.699  -1.338  10.361]
# 3.734 V - 3.710 V: [-11.732  -1.306  10.427]
# 3.720 V - 3.680 V: [-12.009  -1.425  10.584]
# 3.680 V - 3.656 V: [-12.324  -1.444  10.88 ]
# 3.656 V - 3.634 V: [-12.251  -1.05   11.201]
# 3.634 V - 3.614 V: [-12.285  -1.214  11.071]
# 3.614 V - 3.596 V: [-12.615  -1.406  11.209]
# 3.596 V - 3.580 V: [-12.994  -1.59   11.404]
# 3.580 V - 3.566 V: [-13.306  -1.709  11.597]
# 3.566 V - 3.559 V: [-13.935  -2.005  11.93 ]
# 3.559 V - 3.552 V: [-14.291  -2.216  12.075]
# 3.552 V - 3.547 V: [-14.587  -2.409  12.179]
# 3.547 V - 3.542 V: [-14.887  -2.65   12.237]
# 3.542 V - 3.539 V: [-15.693  -4.349  11.344]
# 3.539 V - 3.540 V: No fit within P bounds
# 3.540 V - 3.539 V: [-15.888  -4.594  11.294]
# Figures not shown saved to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Discharge
# Voltage inputs for calculating Free-path Tracer D are out of range. Tracer D will not be calculated.
# Fitted data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Discharge\215 NM9505 30C Discharge Fitted (sphere).xlsx
# Fitted Dc: [4.907e-12 2.950e-12 2.161e-12 1.510e-12 1.304e-12 1.977e-12 2.383e-12
#  2.596e-12 2.991e-12 2.996e-12 2.756e-12 2.362e-12 2.049e-12 1.971e-12
#  1.999e-12 1.853e-12 9.799e-13 4.743e-13 5.605e-13 5.187e-13 2.425e-13
#  1.014e-13 4.948e-14 1.161e-14 5.118e-15 2.587e-15 1.296e-15 2.030e-16
#        nan 1.294e-16]
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Discharge\215 NM9505 30C Discharge Summary.jpg
# 215 NM9505 30C Charge
# Create directory: C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Charge
# Working on cell: 215 NM9505 30C
# Positive electrode active mass: 0.000601 g
# Input cell capacity: 0.000135 Ah
# 3-electrode data detected. Using working potential for calculations and complete cell potential for labelling.
# First signature curve step: 1
# Last signature curve step: 78
# Starting voltage: 3.542 V
# Ending voltage: 4.198 V
# Found 26 charge or discharge steps in signature curve sequences.
# Found 26 signature curves.
# Voltage interval labels: ['3.542 V - 3.542 V', '3.542 V - 3.542 V', '3.542 V - 3.556 V', '3.556 V - 3.602 V', '3.602 V - 3.639 V', '3.639 V - 3.667 V', '3.667 V - 3.692 V', '3.686 V - 3.712 V', '3.712 V - 3.739 V', '3.739 V - 3.764 V', '3.764 V - 3.790 V', '3.790 V - 3.814 V', '3.814 V - 3.838 V', '3.838 V - 3.863 V', '3.863 V - 3.888 V', '3.888 V - 3.913 V', '3.913 V - 3.939 V', '3.939 V - 3.963 V', '3.963 V - 4.013 V', '4.013 V - 4.036 V', '4.036 V - 4.060 V', '4.060 V - 4.083 V', '4.083 V - 4.108 V', '4.108 V - 4.134 V', '4.134 V - 4.160 V', '4.160 V - 4.186 V']
# Found 26 voltage intervals.
# Parsed data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Charge\215 NM9505 30C Charge Parsed.xlsx
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Charge\215 NM9505 30C Charge Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Charge\215 NM9505 30C Charge Parsed.jpg
# Optimum Parameters: Log(Dc) Log(P) Log(P/Dc)
# 3.542 V - 3.542 V: No fit within P bounds
# 3.542 V - 3.542 V: No fit within P bounds
# 3.542 V - 3.556 V: [-12.136   0.045  12.182]
# 3.556 V - 3.602 V: No fit within P bounds
# 3.602 V - 3.639 V: [-12.33  -0.74  11.59]
# 3.639 V - 3.667 V: [-12.321  -0.811  11.51 ]
# 3.667 V - 3.692 V: [-12.021  -0.928  11.093]
# 3.686 V - 3.712 V: [-11.61   -0.753  10.857]
# 3.712 V - 3.739 V: [-11.684  -0.984  10.7  ]
# 3.739 V - 3.764 V: [-11.715  -1.138  10.578]
# 3.764 V - 3.790 V: [-11.662  -1.189  10.473]
# 3.790 V - 3.814 V: [-11.562  -1.204  10.358]
# 3.814 V - 3.838 V: [-11.51   -1.286  10.224]
# 3.838 V - 3.863 V: [-11.482  -1.36   10.123]
# 3.863 V - 3.888 V: [-11.495  -1.437  10.059]
# 3.888 V - 3.913 V: [-11.548  -1.488  10.06 ]
# 3.913 V - 3.939 V: [-11.637  -1.522  10.115]
# 3.939 V - 3.963 V: [-11.828  -1.592  10.236]
# 3.963 V - 4.013 V: [-11.921  -1.589  10.332]
# 4.013 V - 4.036 V: [-11.656  -1.371  10.285]
# 4.036 V - 4.060 V: [-11.606  -1.466  10.14 ]
# 4.060 V - 4.083 V: [-11.58  -1.56  10.02]
# 4.083 V - 4.108 V: [-11.598  -1.657   9.94 ]
# 4.108 V - 4.134 V: [-11.62   -1.681   9.939]
# 4.134 V - 4.160 V: [-11.692  -1.679  10.013]
# 4.160 V - 4.186 V: [-12.515  -2.093  10.422]
# Figures not shown saved to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Charge
# Voltage inputs for calculating Free-path Tracer D are out of range. Tracer D will not be calculated.
# Fitted data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Charge\215 NM9505 30C Charge Fitted (sphere).xlsx
# Fitted Dc: [      nan       nan 7.305e-13       nan 4.674e-13 4.778e-13 9.517e-13
#  2.453e-12 2.072e-12 1.926e-12 2.178e-12 2.744e-12 3.092e-12 3.295e-12
#  3.195e-12 2.834e-12 2.305e-12 1.485e-12 1.199e-12 2.206e-12 2.478e-12
#  2.632e-12 2.524e-12 2.399e-12 2.032e-12 3.058e-13]
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\215\215 NM9505 30C Charge\215 NM9505 30C Charge Summary.jpg
# 217 NM9505 30C Discharge
# Create directory: C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Discharge
# Working on cell: 217 NM9505 30C
# Positive electrode active mass: 0.000743 g
# Input cell capacity: 0.000167 Ah
# 3-electrode data detected. Using working potential for calculations and complete cell potential for labelling.
# First signature curve step: 1
# Last signature curve step: 93
# Starting voltage: 4.080 V
# Ending voltage: 3.451 V
# Found 31 charge or discharge steps in signature curve sequences.
# Found 31 signature curves.
# Voltage interval labels: ['4.080 V - 4.078 V', '4.078 V - 4.055 V', '4.055 V - 4.030 V', '4.030 V - 4.004 V', '4.004 V - 3.980 V', '3.980 V - 3.955 V', '3.955 V - 3.930 V', '3.930 V - 3.905 V', '3.905 V - 3.880 V', '3.880 V - 3.855 V', '3.855 V - 3.829 V', '3.829 V - 3.804 V', '3.804 V - 3.779 V', '3.779 V - 3.755 V', '3.755 V - 3.730 V', '3.730 V - 3.706 V', '3.711 V - 3.678 V', '3.678 V - 3.654 V', '3.654 V - 3.631 V', '3.631 V - 3.610 V', '3.610 V - 3.591 V', '3.591 V - 3.575 V', '3.575 V - 3.558 V', '3.558 V - 3.550 V', '3.550 V - 3.544 V', '3.544 V - 3.538 V', '3.538 V - 3.534 V', '3.534 V - 3.530 V', '3.530 V - 3.532 V', '3.532 V - 3.531 V', '3.531 V - 3.529 V']
# Found 31 voltage intervals.
# Parsed data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Discharge\217 NM9505 30C Discharge Parsed.xlsx
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Discharge\217 NM9505 30C Discharge Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Discharge\217 NM9505 30C Discharge Parsed.jpg
# Optimum Parameters: Log(Dc) Log(P) Log(P/Dc)
# 4.080 V - 4.078 V: [-10.936  -1.303   9.634]
# 4.078 V - 4.055 V: [-11.254  -1.536   9.718]
# 4.055 V - 4.030 V: [-11.405  -1.582   9.823]
# 4.030 V - 4.004 V: [-11.566  -1.594   9.972]
# 4.004 V - 3.980 V: [-11.556  -1.466  10.091]
# 3.980 V - 3.955 V: [-11.288  -1.314   9.974]
# 3.955 V - 3.930 V: [-11.207  -1.379   9.828]
# 3.930 V - 3.905 V: [-11.161  -1.425   9.736]
# 3.905 V - 3.880 V: [-11.122  -1.457   9.665]
# 3.880 V - 3.855 V: [-11.15   -1.511   9.639]
# 3.855 V - 3.829 V: [-11.211  -1.539   9.672]
# 3.829 V - 3.804 V: [-11.315  -1.551   9.765]
# 3.804 V - 3.779 V: [-11.393  -1.521   9.873]
# 3.779 V - 3.755 V: [-11.43   -1.463   9.967]
# 3.755 V - 3.730 V: [-11.442  -1.394  10.048]
# 3.730 V - 3.706 V: [-11.501  -1.363  10.137]
# 3.711 V - 3.678 V: [-11.796  -1.43   10.366]
# 3.678 V - 3.654 V: [-12.158  -1.502  10.656]
# 3.654 V - 3.631 V: [-11.98  -0.98  11.  ]
# 3.631 V - 3.610 V: [-11.965  -1.138  10.828]
# 3.610 V - 3.591 V: [-12.428  -1.439  10.988]
# 3.591 V - 3.575 V: [-12.914  -1.682  11.232]
# 3.575 V - 3.558 V: [-13.245  -1.725  11.52 ]
# 3.558 V - 3.550 V: [-13.817  -1.966  11.851]
# 3.550 V - 3.544 V: [-14.207  -2.185  12.022]
# 3.544 V - 3.538 V: [-14.539  -2.423  12.116]
# 3.538 V - 3.534 V: [-14.75   -2.627  12.123]
# 3.534 V - 3.530 V: [-15.496  -4.413  11.083]
# 3.530 V - 3.532 V: No fit within P bounds
# 3.532 V - 3.531 V: [-15.746  -4.675  11.071]
# 3.531 V - 3.529 V: [-15.556  -4.726  10.83 ]
# Figures not shown saved to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Discharge
# Voltage inputs for calculating Free-path Tracer D are out of range. Tracer D will not be calculated.
# Fitted data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Discharge\217 NM9505 30C Discharge Fitted (sphere).xlsx
# Fitted Dc: [1.158e-11 5.568e-12 3.937e-12 2.719e-12 2.778e-12 5.154e-12 6.206e-12
#  6.908e-12 7.549e-12 7.082e-12 6.146e-12 4.837e-12 4.042e-12 3.716e-12
#  3.615e-12 3.158e-12 1.601e-12 6.953e-13 1.048e-12 1.084e-12 3.735e-13
#  1.219e-13 5.689e-14 1.524e-14 6.213e-15 2.888e-15 1.777e-15 3.192e-16
#        nan 1.795e-16 2.782e-16]
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Discharge\217 NM9505 30C Discharge Summary.jpg
# 217 NM9505 30C Charge
# Create directory: C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Charge
# Working on cell: 217 NM9505 30C
# Positive electrode active mass: 0.000743 g
# Input cell capacity: 0.000167 Ah
# 3-electrode data detected. Using working potential for calculations and complete cell potential for labelling.
# First signature curve step: 1
# Last signature curve step: 78
# Starting voltage: 3.532 V
# Ending voltage: 4.198 V
# Found 26 charge or discharge steps in signature curve sequences.
# Found 26 signature curves.
# Voltage interval labels: ['3.532 V - 3.532 V', '3.532 V - 3.538 V', '3.538 V - 3.571 V', '3.571 V - 3.612 V', '3.612 V - 3.644 V', '3.644 V - 3.671 V', '3.671 V - 3.696 V', '3.694 V - 3.719 V', '3.719 V - 3.745 V', '3.745 V - 3.770 V', '3.770 V - 3.795 V', '3.795 V - 3.820 V', '3.820 V - 3.845 V', '3.845 V - 3.870 V', '3.870 V - 3.895 V', '3.895 V - 3.920 V', '3.920 V - 3.945 V', '3.945 V - 3.970 V', '3.970 V - 4.020 V', '4.020 V - 4.044 V', '4.044 V - 4.069 V', '4.069 V - 4.093 V', '4.093 V - 4.118 V', '4.118 V - 4.143 V', '4.143 V - 4.169 V', '4.169 V - 4.190 V']
# Found 26 voltage intervals.
# Parsed data exporting to:
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Charge\217 NM9505 30C Charge Parsed.xlsx
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Charge\217 NM9505 30C Charge Protocol.jpg
# C:\Users\Mitch\Lab\Atlung Modeling\AMIDR\Analyzed Data\217\217 NM9505 30C Charge\217 NM9505 30C Charge Parsed.jpg
# Optimum Parameters: Log(Dc) Log(P) Log(P/Dc)
# 3.532 V - 3.532 V: No fit within P bounds
# 3.532 V - 3.538 V: No fit within P bounds
# 3.538 V - 3.571 V: [-11.998   0.219  12.217]
# 3.571 V - 3.612 V: [-12.317  -0.678  11.639]
# 3.612 V - 3.644 V: [-12.488  -1.134  11.354]
# 3.644 V - 3.671 V: [-12.006  -0.755  11.25 ]
# 3.671 V - 3.696 V: [-11.873  -1.059  10.814]
# 3.694 V - 3.719 V: [-11.606  -1.028  10.578]
# 3.719 V - 3.745 V: [-11.592  -1.191  10.401]
# 3.745 V - 3.770 V: [-11.574  -1.306  10.267]
# 3.770 V - 3.795 V: [-11.444  -1.297  10.148]
# 3.795 V - 3.820 V: [-11.281  -1.282   9.999]
# 3.820 V - 3.845 V: [-11.165  -1.318   9.848]
# 3.845 V - 3.870 V: [-11.107  -1.366   9.74 ]
# 3.870 V - 3.895 V: [-11.138  -1.429   9.71 ]
# 3.895 V - 3.920 V: [-11.243  -1.531   9.712]
# 3.920 V - 3.945 V: [-11.397  -1.622   9.775]
# 3.945 V - 3.970 V: [-11.644  -1.726   9.917]
# 3.970 V - 4.020 V: [-11.711  -1.683  10.028]
